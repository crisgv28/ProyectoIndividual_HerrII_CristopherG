# %% [markdown]
# <a href="https://colab.research.google.com/github/crisgv28/ProyectoIndividual_HerrII_CristopherG/blob/main/PruebasColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/crisgv28/ProyectoIndividual_HerrII_CristopherG.git
# Out:
# Cloning into 'ProyectoIndividual_HerrII_CristopherG'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 74 (delta 20), reused 57 (delta 11), pack-reused 8
# Receiving objects: 100% (74/74), 43.55 MiB | 24.58 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
from ProyectoIndividual_HerrII_CristopherG.cod.DetectorEmocion import DetectorEmocion

# %%
# !unrar x -Y "/content/ProyectoIndividual_HerrII_CristopherG/data/images.rar" "/content/"
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/images/validation/happy                          OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# Definimos las rutas de la data de entrenamiento y validación
ruta_data_train = '/content/images/train'
ruta_data_val = '/content/images/validation'

# Definimos otros parámetros importantes para el modelo
ancho = 48 # parametros para redimensionar images del modelo
largo = 48
num_clases = 7 # cantidad de tipos de clasificacion
epocas = 50 # cantidad de epocas del modelo
tamano_lote = 64 # tamaño del lote en cada entrenamiento
nombres_Declases = ['angry','disgust','fear','happy','neutral','sad','surprise'] # nombre de cada categoria

# %%
# Creamos el objeto modelo de la clase DetectorEmocion
modelo = DetectorEmocion(ancho, largo, num_clases, epocas, tamano_lote, nombres_Declases, ruta_data_train, ruta_data_val)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %%
modelo.compilar_modelo()

# %%
modelo.entrenar_modelo()
# Out:
# Epoch 1/50
# 450/450 [==============================] - 26s 35ms/step - loss: 1.9829 - accuracy: 0.2190 - val_loss: 1.8041 - val_accuracy: 0.2307
# Epoch 2/50
# 450/450 [==============================] - 15s 32ms/step - loss: 1.8597 - accuracy: 0.2576 - val_loss: 1.7573 - val_accuracy: 0.3119
# Epoch 3/50
# 450/450 [==============================] - 15s 33ms/step - loss: 1.7782 - accuracy: 0.2946 - val_loss: 1.6750 - val_accuracy: 0.3506
# Epoch 4/50
# 450/450 [==============================] - 14s 31ms/step - loss: 1.6830 - accuracy: 0.3432 - val_loss: 1.6406 - val_accuracy: 0.3795
# Epoch 5/50
# 450/450 [==============================] - 15s 33ms/step - loss: 1.6185 - accuracy: 0.3690 - val_loss: 1.5971 - val_accuracy: 0.3947
# Epoch 6/50
# 450/450 [==============================] - 15s 32ms/step - loss: 1.5728 - accuracy: 0.3879 - val_loss: 1.5202 - val_accuracy: 0.4172
# Epoch 7/50
# ...

# %%
# Guardar el modelo
modelo.guardar_modelo("modelo2.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Cargar el modelo entrenado
modelo.cargar_modelo_entrenado("modelo2.h5")

# %%
# Realizar una predicción en una imagen
imagen_por_predecir = "/content/images/validation/surprise/10185.jpg"
clase_predecida = modelo.detectar(imagen_por_predecir)
print(f'La persona está: {clase_predecida}')
# Out:
# 1/1 [==============================] - 1s 634ms/step
# La persona está: surprise

# %%
# Realizar una predicción en una imagen
imagen_por_predecir = "/content/im1.jpg"
clase_predecida = modelo.detectar(imagen_por_predecir)
print(f'La persona está: {clase_predecida}')
# Out:
# 1/1 [==============================] - 0s 26ms/step
# La persona está: happy

# %%
# Realizar una predicción en una imagen
imagen_por_predecir = "/content/im2.jpeg"
clase_predecida = modelo.detectar(imagen_por_predecir)
print(f'La persona está: {clase_predecida}')
# Out:
# 1/1 [==============================] - 0s 17ms/step
# La persona está: neutral

# %%
# Realizar una predicción en una imagen
imagen_por_predecir = "/content/im3.jpg"
clase_predecida = modelo.detectar(imagen_por_predecir)
print(f'La persona está: {clase_predecida}')
# Out:
# 1/1 [==============================] - 0s 25ms/step
# La persona está: fear

# %%
# Realizar una predicción en una imagen
imagen_por_predecir = "/content/im4.jpg"
clase_predecida = modelo.detectar(imagen_por_predecir)
print(f'La persona está: {clase_predecida}')
# Out:
# 1/1 [==============================] - 0s 18ms/step
# La persona está: sad

# %%
# Realizar una predicción en una imagen
imagen_por_predecir = "/content/im5.jpg"
clase_predecida = modelo.detectar(imagen_por_predecir)
print(f'La persona está: {clase_predecida}')
# Out:
# 1/1 [==============================] - 0s 18ms/step
# La persona está: neutral

# %%
# Realizar una predicción en una imagen
imagen_por_predecir = "/content/im6.jpg"
clase_predecida = modelo.detectar(imagen_por_predecir)
print(f'La persona está: {clase_predecida}')
# Out:
# 1/1 [==============================] - 0s 30ms/step
# La persona está: angry

# %%
# Realizar una predicción en una imagen
imagen_por_predecir = "/content/im7.jpg"
clase_predecida = modelo.detectar(imagen_por_predecir)
print(f'La persona está: {clase_predecida}')
# Out:
# 1/1 [==============================] - 0s 17ms/step
# La persona está: angry

# %%
# Realizar una predicción en una imagen
imagen_por_predecir = "/content/im10.jpg"
clase_predecida = modelo.detectar(imagen_por_predecir)
print(f'La persona está: {clase_predecida}')
# Out:
# 1/1 [==============================] - 0s 18ms/step
# La persona está: happy

# %%
# Evaluar el modelo
modelo.evaluar_modelo()
# Out:
# Found 7066 images belonging to 7 classes.
# 111/111 [==============================] - 2s 20ms/step
